# %%
# %run ./../single_neuron_util_unitless.ipynb

# %%
perform_single_neuron_test(a=0.1, b=0.25, I_ext=0., do_plot=True, print_info=True);
# Out:
# a=0.10000, b=0.250, I_ext=0.0, firing rate: 0.00

# %%
perform_single_neuron_test(a=0.1, b=0.25, I_ext=0.77, do_plot=True, print_info=True, timesteps=230);
# Out:
# a=0.10000, b=0.250, I_ext=0.77, firing rate: 17.39

# %%
perform_single_neuron_test(a=0.1, b=0.25, I_ext=0.77, do_plot=True, print_info=True);
# Out:
# a=0.10000, b=0.250, I_ext=0.77, firing rate: 17.58

# %%
perform_single_neuron_test(a=0.1, b=0.25, I_ext=-1, do_plot=True, print_info=True);
# Out:
# a=0.10000, b=0.250, I_ext=-1, firing rate: 0.00

# %%
# burst test

# %%
perform_single_neuron_test_with_current_for_1_ms(a=0.1, b=0.25, I_ext=100, do_plot=True, print_info=True);
# Out:
# a=0.10000, b=0.250, I_ext=100, firing rate: 28.17

# %%
perform_single_neuron_test(a=0.01, b=0.31, I_ext=0.1, do_plot=True, print_info=True);
# Out:
# a=0.01000, b=0.310, I_ext=0.1, firing rate: 7.81
