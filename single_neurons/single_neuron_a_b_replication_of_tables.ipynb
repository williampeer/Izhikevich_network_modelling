# %%
# shared function for the single neuron test, implemented using Brian.
# %run ./../single_neuron_util_unitless.ipynb

# %%
# tables 6 and 7, a 6x6 replication of their factorial design for single neurons
perform_single_neuron_test(a=0.015, b=0.15)
perform_single_neuron_test(a=0.015, b=0.26)
perform_single_neuron_test(a=0.015, b=0.37)
perform_single_neuron_test(a=0.015, b=0.48)
perform_single_neuron_test(a=0.015, b=0.59)
perform_single_neuron_test(a=0.015, b=0.70)
print()
perform_single_neuron_test(a=0.022, b=0.15)
perform_single_neuron_test(a=0.022, b=0.26)
perform_single_neuron_test(a=0.022, b=0.37)
perform_single_neuron_test(a=0.022, b=0.48)
perform_single_neuron_test(a=0.022, b=0.59)
perform_single_neuron_test(a=0.022, b=0.70)
print()
perform_single_neuron_test(a=0.029, b=0.15)
perform_single_neuron_test(a=0.029, b=0.26)
perform_single_neuron_test(a=0.029, b=0.37)
perform_single_neuron_test(a=0.029, b=0.48)
perform_single_neuron_test(a=0.029, b=0.59)
perform_single_neuron_test(a=0.029, b=0.70)
print()
perform_single_neuron_test(a=0.036, b=0.15)
perform_single_neuron_test(a=0.036, b=0.26)
perform_single_neuron_test(a=0.036, b=0.37)
perform_single_neuron_test(a=0.036, b=0.48)
perform_single_neuron_test(a=0.036, b=0.59)
perform_single_neuron_test(a=0.036, b=0.70)
print()
perform_single_neuron_test(a=0.043, b=0.15)
perform_single_neuron_test(a=0.043, b=0.26)
perform_single_neuron_test(a=0.043, b=0.37)
perform_single_neuron_test(a=0.043, b=0.48)
perform_single_neuron_test(a=0.043, b=0.59)
perform_single_neuron_test(a=0.043, b=0.70)
print()
perform_single_neuron_test(a=0.050, b=0.15)
perform_single_neuron_test(a=0.050, b=0.26)
perform_single_neuron_test(a=0.050, b=0.37)
perform_single_neuron_test(a=0.050, b=0.48)
perform_single_neuron_test(a=0.050, b=0.59)
perform_single_neuron_test(a=0.050, b=0.70);
# Out:
# a=0.01500, b=0.150, I_ext=0, firing rate: 0.00
# a=0.01500, b=0.260, I_ext=0, firing rate: 0.00
# a=0.01500, b=0.370, I_ext=0, firing rate: 17.58
# a=0.01500, b=0.480, I_ext=0, firing rate: 29.30
# a=0.01500, b=0.590, I_ext=0, firing rate: 41.02
# a=0.01500, b=0.700, I_ext=0, firing rate: 52.73
#
# a=0.02200, b=0.150, I_ext=0, firing rate: 0.00
# a=0.02200, b=0.260, I_ext=0, firing rate: 0.00
# a=0.02200, b=0.370, I_ext=0, firing rate: 25.39
# a=0.02200, b=0.480, I_ext=0, firing rate: 41.02
# a=0.02200, b=0.590, I_ext=0, firing rate: 56.64
# a=0.02200, b=0.700, I_ext=0, firing rate: 70.31
#
# a=0.02900, b=0.150, I_ext=0, firing rate: 0.00
# a=0.02900, b=0.260, I_ext=0, firing rate: 0.00
# a=0.02900, b=0.370, I_ext=0, firing rate: 33.20
# a=0.02900, b=0.480, I_ext=0, firing rate: 52.73
# a=0.02900, b=0.590, I_ext=0, firing rate: 70.31
# a=0.02900, b=0.700, I_ext=0, firing rate: 87.89
#
# a=0.03600, b=0.150, I_ext=0, firing rate: 0.00
# a=0.03600, b=0.260, I_ext=0, firing rate: 0.00
# ...

# %%
# table 9 - FD did not predict freq.: - lower, stabler rates, more slowly increasing due to v. low a ?
perform_single_neuron_test(a=0.0050, b=0.3850)
perform_single_neuron_test(a=0.0050, b=0.4200)
perform_single_neuron_test(a=0.0050, b=0.4550);
# Out:
# a=0.00500, b=0.385, I_ext=0, firing rate: 5.86
# a=0.00500, b=0.420, I_ext=0, firing rate: 7.81
# a=0.00500, b=0.455, I_ext=0, firing rate: 7.81

# %%
# table 10 - FD did not predict rates
perform_single_neuron_test(a=0.02, b=0.07)
perform_single_neuron_test(a=0.0225, b=0.07)
perform_single_neuron_test(a=0.025, b=0.07);
# Out:
# a=0.02000, b=0.070, I_ext=0, firing rate: 0.00
# a=0.02250, b=0.070, I_ext=0, firing rate: 0.00
# a=0.02500, b=0.070, I_ext=0, firing rate: 0.00

# %%
# table 11:
perform_single_neuron_test(a=0.0075, b=0.3150)
perform_single_neuron_test(a=0.01, b=0.21)
perform_single_neuron_test(a=0.0125, b=0.175);
# Out:
# a=0.00750, b=0.315, I_ext=0, firing rate: 5.86
# a=0.01000, b=0.210, I_ext=0, firing rate: 0.00
# a=0.01250, b=0.175, I_ext=0, firing rate: 0.00

# %%
# table 12:
perform_single_neuron_test(a=0.0225, b=0.665)
perform_single_neuron_test(a=0.025, b=0.56)
perform_single_neuron_test(a=0.0275, b=0.525)
perform_single_neuron_test(a=0.03, b=0.49)
perform_single_neuron_test(a=0.0375, b=0.385)
perform_single_neuron_test(a=0.04, b=0.35);
# Out:
# a=0.02250, b=0.665, I_ext=0, firing rate: 68.36
# a=0.02500, b=0.560, I_ext=0, firing rate: 58.59
# a=0.02750, b=0.525, I_ext=0, firing rate: 56.64
# a=0.03000, b=0.490, I_ext=0, firing rate: 54.69
# a=0.03750, b=0.385, I_ext=0, firing rate: 42.97
# a=0.04000, b=0.350, I_ext=0, firing rate: 37.11

# %%
# table 13:
perform_single_neuron_test(a=0.0275, b=0.490)
perform_single_neuron_test(a=0.0275, b=0.665);
# Out:
# a=0.02750, b=0.490, I_ext=0, firing rate: 50.78
# a=0.02750, b=0.665, I_ext=0, firing rate: 80.08

# %%
# table 14:
perform_single_neuron_test(a=0.05, b=0.665)
perform_single_neuron_test(a=0.05, b=0.700);
# Out:
# a=0.05000, b=0.665, I_ext=0, firing rate: 121.09
# a=0.05000, b=0.700, I_ext=0, firing rate: 128.91
