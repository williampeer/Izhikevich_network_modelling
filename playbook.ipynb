# %%
# %run ./single_neuron_util_unitless.ipynb

# %%
perform_single_neuron_test_with_current_for_1_ms(a=0.1, b=0.25);
# Out:
# a=0.10000, b=0.250, I_ext=100, firing rate: 28.17

# %%
perform_single_neuron_test(a=0.01, b=0.27, timesteps=1024);
# Out:
# a=0.01000, b=0.270, I_ext=0, firing rate: 4.88

# %%
# %run ./network_util_unitless_replicated_perturbation_method.ipynb
# %load_ext memory_profiler
# %time %memit run_once_and_plot(a=0.005, b=0.42, ws_e=11, ws_i=11, n=500, tau_g=5.0*ms, steps=4096)
# Out:
# Parameters: a=0.005, b=0.42, ws_e=11, ws_i=11, n=500, tau_g=0.005
# frequency with highest energy: 4.638671875
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# peak memory: 456.86 MiB, increment: 310.25 MiB
# CPU times: user 55.2 s, sys: 596 ms, total: 55.8 s
# Wall time: 1min

# %%
# %run ./network_util_unitless_gaussian_noise.ipynb
# %load_ext memory_profiler
# %time %memit run_once_and_plot_gaussian(a=0.005, b=0.42, ws_e=11, ws_i=11, n=500, tau_g=5.0*ms, steps=4096)
# Out:
# Parameters: a=0.005, b=0.42, ws_e=11, ws_i=11, n=500, tau_g=0.005
# t1: 4.096 s
# frequency with highest energy: 4.638671875
# peak memory: 473.66 MiB, increment: 291.11 MiB
# CPU times: user 31.4 s, sys: 553 ms, total: 31.9 s
# Wall time: 34.7 s
